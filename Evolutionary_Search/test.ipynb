# %%
from ofa.imagenet_classification.elastic_nn.networks.ofa_mbv3 import OFAMobileNetV3
from ofa.utils import download_url
import torch
# Out:
# x:\Softwares\anaconda\envs\ml\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
net_id  = 'ofa_mbv3_d234_e346_k357_w1.2'
url_base = "https://raw.githubusercontent.com/han-cai/files/master/ofa/ofa_nets/"

ofa_network = OFAMobileNetV3(
            dropout_rate=0,
            width_mult=1.2,
            ks_list=[3, 5, 7],
            expand_ratio_list=[3, 4, 6],
            depth_list=[2, 3, 4],
        )

pt_path = download_url(url_base + net_id, model_dir=".torch/ofa_nets")
init = torch.load(pt_path, map_location="cpu")["state_dict"]
ofa_network.load_state_dict(init)
print('Supernetwork Ready')
# Out:
# Supernetwork Ready

# %%
from ofa.imagenet_classification.elastic_nn.networks.ofa_mbv3 import OFAMobileNetV3
import torch
from ofa.utils import download_url
# Out:
# x:\Softwares\anaconda\envs\ml\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
image_size = 224

cfg1 = ofa_network.sample_active_subnet()
subnet = ofa_network.get_active_subnet(preserve_weight=True)

#manualy set the subnet 
cfg = ofa_network.set_active_subnet(ks=3, e=6, d=4)

cfg = ofa_network.set_max_net()
subnet2 = ofa_network.get_active_subnet(preserve_weight=True)

# %%
for n, m in ofa_network.named_parameters():
    print(n)
# Out:
# first_conv.conv.weight
# first_conv.bn.weight
# first_conv.bn.bias
# blocks.0.conv.depth_conv.conv.weight
# blocks.0.conv.depth_conv.bn.weight
# blocks.0.conv.depth_conv.bn.bias
# blocks.0.conv.point_linear.conv.weight
# blocks.0.conv.point_linear.bn.weight
# blocks.0.conv.point_linear.bn.bias
# blocks.1.conv.inverted_bottleneck.conv.conv.weight
# blocks.1.conv.inverted_bottleneck.bn.bn.weight
# blocks.1.conv.inverted_bottleneck.bn.bn.bias
# blocks.1.conv.depth_conv.conv.5to3_matrix
# blocks.1.conv.depth_conv.conv.7to5_matrix
# blocks.1.conv.depth_conv.conv.conv.weight
# blocks.1.conv.depth_conv.bn.bn.weight
# blocks.1.conv.depth_conv.bn.bn.bias
# blocks.1.conv.point_linear.conv.conv.weight
# blocks.1.conv.point_linear.bn.bn.weight
# blocks.1.conv.point_linear.bn.bn.bias
# blocks.2.conv.inverted_bottleneck.conv.conv.weight
# blocks.2.conv.inverted_bottleneck.bn.bn.weight
# blocks.2.conv.inverted_bottleneck.bn.bn.bias
# blocks.2.conv.depth_conv.conv.5to3_matrix
# blocks.2.conv.depth_conv.conv.7to5_matrix
# blocks.2.conv.depth_conv.conv.conv.weight
# blocks.2.conv.depth_conv.bn.bn.weight
# blocks.2.conv.depth_conv.bn.bn.bias
# blocks.2.conv.point_linear.conv.conv.weight
# blocks.2.conv.point_linear.bn.bn.weight
# blocks.2.conv.point_linear.bn.bn.bias
# blocks.3.conv.inverted_bottleneck.conv.conv.weight
# blocks.3.conv.inverted_bottleneck.bn.bn.weight
# blocks.3.conv.inverted_bottleneck.bn.bn.bias
# blocks.3.conv.depth_conv.conv.5to3_matrix
# blocks.3.conv.depth_conv.conv.7to5_matrix
# blocks.3.conv.depth_conv.conv.conv.weight
# blocks.3.conv.depth_conv.bn.bn.weight
# blocks.3.conv.depth_conv.bn.bn.bias
# blocks.3.conv.point_linear.conv.conv.weight
# blocks.3.conv.point_linear.bn.bn.weight
# blocks.3.conv.point_linear.bn.bn.bias
# blocks.4.conv.inverted_bottleneck.conv.conv.weight
# blocks.4.conv.inverted_bottleneck.bn.bn.weight
# blocks.4.conv.inverted_bottleneck.bn.bn.bias
# blocks.4.conv.depth_conv.conv.5to3_matrix
# blocks.4.conv.depth_conv.conv.7to5_matrix
# blocks.4.conv.depth_conv.conv.conv.weight
# blocks.4.conv.depth_conv.bn.bn.weight
# blocks.4.conv.depth_conv.bn.bn.bias
# blocks.4.conv.point_linear.conv.conv.weight
# blocks.4.conv.point_linear.bn.bn.weight
# blocks.4.conv.point_linear.bn.bn.bias
# blocks.5.conv.inverted_bottleneck.conv.conv.weight
# blocks.5.conv.inverted_bottleneck.bn.bn.weight
# blocks.5.conv.inverted_bottleneck.bn.bn.bias
# blocks.5.conv.depth_conv.conv.5to3_matrix
# blocks.5.conv.depth_conv.conv.7to5_matrix
# blocks.5.conv.depth_conv.conv.conv.weight
# blocks.5.conv.depth_conv.bn.bn.weight
# blocks.5.conv.depth_conv.bn.bn.bias
# blocks.5.conv.depth_conv.se.fc.reduce.weight
# blocks.5.conv.depth_conv.se.fc.reduce.bias
# blocks.5.conv.depth_conv.se.fc.expand.weight
# blocks.5.conv.depth_conv.se.fc.expand.bias
# blocks.5.conv.point_linear.conv.conv.weight
# blocks.5.conv.point_linear.bn.bn.weight
# blocks.5.conv.point_linear.bn.bn.bias
# blocks.6.conv.inverted_bottleneck.conv.conv.weight
# blocks.6.conv.inverted_bottleneck.bn.bn.weight
# blocks.6.conv.inverted_bottleneck.bn.bn.bias
# blocks.6.conv.depth_conv.conv.5to3_matrix
# blocks.6.conv.depth_conv.conv.7to5_matrix
# blocks.6.conv.depth_conv.conv.conv.weight
# blocks.6.conv.depth_conv.bn.bn.weight
# blocks.6.conv.depth_conv.bn.bn.bias
# blocks.6.conv.depth_conv.se.fc.reduce.weight
# blocks.6.conv.depth_conv.se.fc.reduce.bias
# blocks.6.conv.depth_conv.se.fc.expand.weight
# blocks.6.conv.depth_conv.se.fc.expand.bias
# blocks.6.conv.point_linear.conv.conv.weight
# blocks.6.conv.point_linear.bn.bn.weight
# blocks.6.conv.point_linear.bn.bn.bias
# blocks.7.conv.inverted_bottleneck.conv.conv.weight
# blocks.7.conv.inverted_bottleneck.bn.bn.weight
# blocks.7.conv.inverted_bottleneck.bn.bn.bias
# blocks.7.conv.depth_conv.conv.5to3_matrix
# blocks.7.conv.depth_conv.conv.7to5_matrix
# blocks.7.conv.depth_conv.conv.conv.weight
# blocks.7.conv.depth_conv.bn.bn.weight
# blocks.7.conv.depth_conv.bn.bn.bias
# blocks.7.conv.depth_conv.se.fc.reduce.weight
# blocks.7.conv.depth_conv.se.fc.reduce.bias
# blocks.7.conv.depth_conv.se.fc.expand.weight
# blocks.7.conv.depth_conv.se.fc.expand.bias
# blocks.7.conv.point_linear.conv.conv.weight
# blocks.7.conv.point_linear.bn.bn.weight
# blocks.7.conv.point_linear.bn.bn.bias
# blocks.8.conv.inverted_bottleneck.conv.conv.weight
# blocks.8.conv.inverted_bottleneck.bn.bn.weight
# blocks.8.conv.inverted_bottleneck.bn.bn.bias
# blocks.8.conv.depth_conv.conv.5to3_matrix
# blocks.8.conv.depth_conv.conv.7to5_matrix
# blocks.8.conv.depth_conv.conv.conv.weight
# blocks.8.conv.depth_conv.bn.bn.weight
# blocks.8.conv.depth_conv.bn.bn.bias
# blocks.8.conv.depth_conv.se.fc.reduce.weight
# blocks.8.conv.depth_conv.se.fc.reduce.bias
# blocks.8.conv.depth_conv.se.fc.expand.weight
# blocks.8.conv.depth_conv.se.fc.expand.bias
# blocks.8.conv.point_linear.conv.conv.weight
# blocks.8.conv.point_linear.bn.bn.weight
# blocks.8.conv.point_linear.bn.bn.bias
# blocks.9.conv.inverted_bottleneck.conv.conv.weight
# blocks.9.conv.inverted_bottleneck.bn.bn.weight
# blocks.9.conv.inverted_bottleneck.bn.bn.bias
# blocks.9.conv.depth_conv.conv.5to3_matrix
# blocks.9.conv.depth_conv.conv.7to5_matrix
# blocks.9.conv.depth_conv.conv.conv.weight
# blocks.9.conv.depth_conv.bn.bn.weight
# blocks.9.conv.depth_conv.bn.bn.bias
# blocks.9.conv.point_linear.conv.conv.weight
# blocks.9.conv.point_linear.bn.bn.weight
# blocks.9.conv.point_linear.bn.bn.bias
# blocks.10.conv.inverted_bottleneck.conv.conv.weight
# blocks.10.conv.inverted_bottleneck.bn.bn.weight
# blocks.10.conv.inverted_bottleneck.bn.bn.bias
# blocks.10.conv.depth_conv.conv.5to3_matrix
# blocks.10.conv.depth_conv.conv.7to5_matrix
# blocks.10.conv.depth_conv.conv.conv.weight
# blocks.10.conv.depth_conv.bn.bn.weight
# blocks.10.conv.depth_conv.bn.bn.bias
# blocks.10.conv.point_linear.conv.conv.weight
# blocks.10.conv.point_linear.bn.bn.weight
# blocks.10.conv.point_linear.bn.bn.bias
# blocks.11.conv.inverted_bottleneck.conv.conv.weight
# blocks.11.conv.inverted_bottleneck.bn.bn.weight
# blocks.11.conv.inverted_bottleneck.bn.bn.bias
# blocks.11.conv.depth_conv.conv.5to3_matrix
# blocks.11.conv.depth_conv.conv.7to5_matrix
# blocks.11.conv.depth_conv.conv.conv.weight
# blocks.11.conv.depth_conv.bn.bn.weight
# blocks.11.conv.depth_conv.bn.bn.bias
# blocks.11.conv.point_linear.conv.conv.weight
# blocks.11.conv.point_linear.bn.bn.weight
# blocks.11.conv.point_linear.bn.bn.bias
# blocks.12.conv.inverted_bottleneck.conv.conv.weight
# blocks.12.conv.inverted_bottleneck.bn.bn.weight
# blocks.12.conv.inverted_bottleneck.bn.bn.bias
# blocks.12.conv.depth_conv.conv.5to3_matrix
# blocks.12.conv.depth_conv.conv.7to5_matrix
# blocks.12.conv.depth_conv.conv.conv.weight
# blocks.12.conv.depth_conv.bn.bn.weight
# blocks.12.conv.depth_conv.bn.bn.bias
# blocks.12.conv.point_linear.conv.conv.weight
# blocks.12.conv.point_linear.bn.bn.weight
# blocks.12.conv.point_linear.bn.bn.bias
# blocks.13.conv.inverted_bottleneck.conv.conv.weight
# blocks.13.conv.inverted_bottleneck.bn.bn.weight
# blocks.13.conv.inverted_bottleneck.bn.bn.bias
# blocks.13.conv.depth_conv.conv.5to3_matrix
# blocks.13.conv.depth_conv.conv.7to5_matrix
# blocks.13.conv.depth_conv.conv.conv.weight
# blocks.13.conv.depth_conv.bn.bn.weight
# blocks.13.conv.depth_conv.bn.bn.bias
# blocks.13.conv.depth_conv.se.fc.reduce.weight
# blocks.13.conv.depth_conv.se.fc.reduce.bias
# blocks.13.conv.depth_conv.se.fc.expand.weight
# blocks.13.conv.depth_conv.se.fc.expand.bias
# blocks.13.conv.point_linear.conv.conv.weight
# blocks.13.conv.point_linear.bn.bn.weight
# blocks.13.conv.point_linear.bn.bn.bias
# blocks.14.conv.inverted_bottleneck.conv.conv.weight
# blocks.14.conv.inverted_bottleneck.bn.bn.weight
# blocks.14.conv.inverted_bottleneck.bn.bn.bias
# blocks.14.conv.depth_conv.conv.5to3_matrix
# blocks.14.conv.depth_conv.conv.7to5_matrix
# blocks.14.conv.depth_conv.conv.conv.weight
# blocks.14.conv.depth_conv.bn.bn.weight
# blocks.14.conv.depth_conv.bn.bn.bias
# blocks.14.conv.depth_conv.se.fc.reduce.weight
# blocks.14.conv.depth_conv.se.fc.reduce.bias
# blocks.14.conv.depth_conv.se.fc.expand.weight
# blocks.14.conv.depth_conv.se.fc.expand.bias
# blocks.14.conv.point_linear.conv.conv.weight
# blocks.14.conv.point_linear.bn.bn.weight
# blocks.14.conv.point_linear.bn.bn.bias
# blocks.15.conv.inverted_bottleneck.conv.conv.weight
# blocks.15.conv.inverted_bottleneck.bn.bn.weight
# blocks.15.conv.inverted_bottleneck.bn.bn.bias
# blocks.15.conv.depth_conv.conv.5to3_matrix
# blocks.15.conv.depth_conv.conv.7to5_matrix
# blocks.15.conv.depth_conv.conv.conv.weight
# blocks.15.conv.depth_conv.bn.bn.weight
# blocks.15.conv.depth_conv.bn.bn.bias
# blocks.15.conv.depth_conv.se.fc.reduce.weight
# blocks.15.conv.depth_conv.se.fc.reduce.bias
# blocks.15.conv.depth_conv.se.fc.expand.weight
# blocks.15.conv.depth_conv.se.fc.expand.bias
# blocks.15.conv.point_linear.conv.conv.weight
# blocks.15.conv.point_linear.bn.bn.weight
# blocks.15.conv.point_linear.bn.bn.bias
# blocks.16.conv.inverted_bottleneck.conv.conv.weight
# blocks.16.conv.inverted_bottleneck.bn.bn.weight
# blocks.16.conv.inverted_bottleneck.bn.bn.bias
# blocks.16.conv.depth_conv.conv.5to3_matrix
# blocks.16.conv.depth_conv.conv.7to5_matrix
# blocks.16.conv.depth_conv.conv.conv.weight
# blocks.16.conv.depth_conv.bn.bn.weight
# blocks.16.conv.depth_conv.bn.bn.bias
# blocks.16.conv.depth_conv.se.fc.reduce.weight
# blocks.16.conv.depth_conv.se.fc.reduce.bias
# blocks.16.conv.depth_conv.se.fc.expand.weight
# blocks.16.conv.depth_conv.se.fc.expand.bias
# blocks.16.conv.point_linear.conv.conv.weight
# blocks.16.conv.point_linear.bn.bn.weight
# blocks.16.conv.point_linear.bn.bn.bias
# blocks.17.conv.inverted_bottleneck.conv.conv.weight
# blocks.17.conv.inverted_bottleneck.bn.bn.weight
# blocks.17.conv.inverted_bottleneck.bn.bn.bias
# blocks.17.conv.depth_conv.conv.5to3_matrix
# blocks.17.conv.depth_conv.conv.7to5_matrix
# blocks.17.conv.depth_conv.conv.conv.weight
# blocks.17.conv.depth_conv.bn.bn.weight
# blocks.17.conv.depth_conv.bn.bn.bias
# blocks.17.conv.depth_conv.se.fc.reduce.weight
# blocks.17.conv.depth_conv.se.fc.reduce.bias
# blocks.17.conv.depth_conv.se.fc.expand.weight
# blocks.17.conv.depth_conv.se.fc.expand.bias
# blocks.17.conv.point_linear.conv.conv.weight
# blocks.17.conv.point_linear.bn.bn.weight
# blocks.17.conv.point_linear.bn.bn.bias
# blocks.18.conv.inverted_bottleneck.conv.conv.weight
# blocks.18.conv.inverted_bottleneck.bn.bn.weight
# blocks.18.conv.inverted_bottleneck.bn.bn.bias
# blocks.18.conv.depth_conv.conv.5to3_matrix
# blocks.18.conv.depth_conv.conv.7to5_matrix
# blocks.18.conv.depth_conv.conv.conv.weight
# blocks.18.conv.depth_conv.bn.bn.weight
# blocks.18.conv.depth_conv.bn.bn.bias
# blocks.18.conv.depth_conv.se.fc.reduce.weight
# blocks.18.conv.depth_conv.se.fc.reduce.bias
# blocks.18.conv.depth_conv.se.fc.expand.weight
# blocks.18.conv.depth_conv.se.fc.expand.bias
# blocks.18.conv.point_linear.conv.conv.weight
# blocks.18.conv.point_linear.bn.bn.weight
# blocks.18.conv.point_linear.bn.bn.bias
# blocks.19.conv.inverted_bottleneck.conv.conv.weight
# blocks.19.conv.inverted_bottleneck.bn.bn.weight
# blocks.19.conv.inverted_bottleneck.bn.bn.bias
# blocks.19.conv.depth_conv.conv.5to3_matrix
# blocks.19.conv.depth_conv.conv.7to5_matrix
# blocks.19.conv.depth_conv.conv.conv.weight
# blocks.19.conv.depth_conv.bn.bn.weight
# blocks.19.conv.depth_conv.bn.bn.bias
# blocks.19.conv.depth_conv.se.fc.reduce.weight
# blocks.19.conv.depth_conv.se.fc.reduce.bias
# blocks.19.conv.depth_conv.se.fc.expand.weight
# blocks.19.conv.depth_conv.se.fc.expand.bias
# blocks.19.conv.point_linear.conv.conv.weight
# blocks.19.conv.point_linear.bn.bn.weight
# blocks.19.conv.point_linear.bn.bn.bias
# blocks.20.conv.inverted_bottleneck.conv.conv.weight
# blocks.20.conv.inverted_bottleneck.bn.bn.weight
# blocks.20.conv.inverted_bottleneck.bn.bn.bias
# blocks.20.conv.depth_conv.conv.5to3_matrix
# blocks.20.conv.depth_conv.conv.7to5_matrix
# blocks.20.conv.depth_conv.conv.conv.weight
# blocks.20.conv.depth_conv.bn.bn.weight
# blocks.20.conv.depth_conv.bn.bn.bias
# blocks.20.conv.depth_conv.se.fc.reduce.weight
# blocks.20.conv.depth_conv.se.fc.reduce.bias
# blocks.20.conv.depth_conv.se.fc.expand.weight
# blocks.20.conv.depth_conv.se.fc.expand.bias
# blocks.20.conv.point_linear.conv.conv.weight
# blocks.20.conv.point_linear.bn.bn.weight
# blocks.20.conv.point_linear.bn.bn.bias
# final_expand_layer.conv.weight
# final_expand_layer.bn.weight
# final_expand_layer.bn.bias
# feature_mix_layer.conv.weight
# classifier.linear.weight
# classifier.linear.bias
